# %%
# To achieve 3 seconds of insertion time on either a hash table or binary tree, a size of n = 100,000 would be needed at minimum.

# %%
# Methods:
# I will write the source code in C++ and plot the result in Python. For my compiler, I am using MinGW as my compiler. I will create an unordered_multimap and choose n = 10. Then I will add 10 pairs of random ints to my map. Using ctime I will record the time in a vector. I will then try n = 100, n = 1000..., and then do the same for a multimap using a binary tree backend. Once I see either structure record a time greater than 3 seconds, I will be finished. Then I will take the elements of the vectors and put them into python lists to graph using matplotlib.

# %%
# Source code can be found at the following github repository

# %%
import matplotlib.pyplot as plt

# %%
hash_times = [0, 0, 0.001, 0.01, 0.127, 1.612, 15.577]

# %%
tree_times = [0, 0, 0.002, 0.014, 0.155, 2.784, 51.046]

# %%
plt.plot(hash_times, label= "Hash Map")
plt.plot(tree_times, label= "Binary Tree")
plt.legend()
plt.title("Dictionary Backend Times")
plt.xlabel("Input Size")
plt.ylabel("Time (seconds)")
plt.xticks([0,1,2,3,4,5, 6], [10,100,1000,10000,100000, 1000000, 10000000])
plt.show()
